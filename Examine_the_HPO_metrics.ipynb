# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %% [markdown]
# block 0103

# %%
path_0103 = "Store_metric_results/block_0103"

# %%
os.listdir(path_0103)
# Out:
# ['hpo_metrics_for_block0103_2.csv',
#  'hpo_metrics_for_block0103_5.csv',
#  'hpo_metrics_for_block0103_4.csv',
#  'hpo_metrics_for_block0103_3.csv',
#  '.ipynb_checkpoints',
#  'hpo_metrics_for_block0103_6.csv',
#  'hpo_metrics_for_block0103_1.csv']

# %%
# get only the csv files
csv_0103 = [file for file in os.listdir(path_0103) if file.split(".")[-1] == 'csv']
csv_0103.sort()

# %%
csv_0103
# Out:
# ['hpo_metrics_for_block0103_1.csv',
#  'hpo_metrics_for_block0103_2.csv',
#  'hpo_metrics_for_block0103_3.csv',
#  'hpo_metrics_for_block0103_4.csv',
#  'hpo_metrics_for_block0103_5.csv',
#  'hpo_metrics_for_block0103_6.csv']

# %%
all_dfs_0103 = []
for csv in csv_0103:
    joined_path = os.path.join(path_0103, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0103.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0103_df = pd.concat(all_dfs_0103, axis = 0).reset_index(drop = True)

# %%
concatenated_0103_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   7.293814
# 1     0.001       -1.0        0       0.001        0.100  36.083185
# 2     0.001       -1.0        0       0.001        0.500  36.084503
# 3     0.001       -1.0        0       0.100        0.001   4.511348
# 4     0.001       -1.0        0       0.100        0.100  29.320053
#
#          mae      corr  avg_width_train  coverage_train
# 0   5.514347  0.632038         5.365048        0.285714
# 1  35.704350 -0.429959        15.964792        0.000000
# 2  35.700725 -0.729948        33.026454        0.000000
# 3   3.493606  0.775766         2.701222        0.285714
# 4  28.697445 -0.733934        15.572870        0.000000

# %%
# sort values wrt width
concatenated_0103_df.sort_values(['avg_width_train']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001   4.574474
# 3      0.001       -1.0        0       0.100        0.001   4.511348
# 15     0.001        0.5        0       0.500        0.001   5.626761
# 6      0.001       -1.0        0       0.500        0.001   6.134040
# 0      0.001       -1.0        0       0.001        0.001   7.293814
# 9      0.001        0.5        0       0.001        0.001   7.302181
# 16     0.001        0.5        0       0.500        0.100   4.081357
# 7      0.001       -1.0        0       0.500        0.100   4.098359
# 4      0.001       -1.0        0       0.100        0.100  29.320053
# 13     0.001        0.5        0       0.100        0.100  29.137106
# 10     0.001        0.5        0       0.001        0.100  36.113816
# 1      0.001       -1.0        0       0.001        0.100  36.083185
# 25     0.100       -1.0        0       0.500        0.100   3.134770
# ...

# %%
# sort values wrt mae
concatenated_0103_df.sort_values(['mae']).head()
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale      rmse       mae  \
# 25       0.1       -1.0        0       0.500        0.100  3.134770  2.481825
# 34       0.1        0.5        0       0.500        0.100  3.203992  2.505594
# 44       0.5       -1.0        0       0.500        0.500  4.315879  2.824284
# 27       0.1        0.5        0       0.001        0.001  4.188532  3.067331
# 53       0.5        0.5        0       0.500        0.500  4.604213  3.118307
#
#         corr  avg_width_train  coverage_train
# 25  0.813911        19.580795             1.0
# 34  0.805098        20.244862             1.0
# 44  0.759460        52.696354             1.0
# 27  0.624579        37.083652             1.0
# 53  0.751310        54.696716             1.0

# %%
# chosen parameters
# wrt width
# 0.001	0.5	0 0.500	0.100	4.081357	3.426384	0.699229	9.597741	0.857143
# 0.001	-1.0 0 0.500 0.100	4.098359	3.448538	0.693140	9.968705	0.857143
# wrt mae
# 0.1	-1.0 0 0.500 0.100 3.134770	2.481825	0.813911	19.580795	1.0
# 0.1	0.5	0 0.500	0.100 3.203992	2.505594	0.805098	20.244862	1.0

# %% [markdown]
# block 0105

# %%
path_0105 = "Store_metric_results/block_0105"

# %%
os.listdir(path_0105)
# Out:
# ['hpo_metrics_for_block0105_5.csv',
#  'hpo_metrics_for_block0105_2.csv',
#  'hpo_metrics_for_block0105_3.csv',
#  'hpo_metrics_for_block0105_4.csv',
#  '.ipynb_checkpoints',
#  'hpo_metrics_for_block0105_1.csv',
#  'hpo_metrics_for_block0105_6.csv']

# %%
# get only the csv files
csv_0105 = [file for file in os.listdir(path_0105) if file.split(".")[-1] == 'csv']
csv_0105.sort()

# %%
csv_0105
# Out:
# ['hpo_metrics_for_block0105_1.csv',
#  'hpo_metrics_for_block0105_2.csv',
#  'hpo_metrics_for_block0105_3.csv',
#  'hpo_metrics_for_block0105_4.csv',
#  'hpo_metrics_for_block0105_5.csv',
#  'hpo_metrics_for_block0105_6.csv']

# %%
all_dfs_0105 = []
for csv in csv_0105:
    joined_path = os.path.join(path_0105, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0105.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0105_df = pd.concat(all_dfs_0105, axis = 0).reset_index(drop = True)

# %%
concatenated_0105_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   9.409783
# 1     0.001       -1.0        0       0.001        0.100  41.882654
# 2     0.001       -1.0        0       0.001        0.500  41.915170
# 3     0.001       -1.0        0       0.100        0.001   8.177548
# 4     0.001       -1.0        0       0.100        0.100  32.185081
#
#          mae      corr  avg_width_train  coverage_train
# 0   6.715131  0.633133         5.619919        0.285714
# 1  40.722276 -0.781188        16.672357        0.000000
# 2  40.743251 -0.478224        34.926005        0.000000
# 3   6.634099  0.569040         3.952131        0.142857
# 4  30.221911 -0.515671        16.820209        0.000000

# %%
# sort values wrt width
concatenated_0105_df.sort_values(['avg_width_train']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 15     0.001        0.5        0       0.500        0.001   9.676212
# 6      0.001       -1.0        0       0.500        0.001   9.347309
# 12     0.001        0.5        0       0.100        0.001   8.225380
# 3      0.001       -1.0        0       0.100        0.001   8.177548
# 9      0.001        0.5        0       0.001        0.001   9.410910
# 0      0.001       -1.0        0       0.001        0.001   9.409783
# 7      0.001       -1.0        0       0.500        0.100  11.122555
# 16     0.001        0.5        0       0.500        0.100  11.073558
# 10     0.001        0.5        0       0.001        0.100  41.856890
# 1      0.001       -1.0        0       0.001        0.100  41.882654
# 4      0.001       -1.0        0       0.100        0.100  32.185081
# 13     0.001        0.5        0       0.100        0.100  32.194313
# 34     0.100        0.5        0       0.500        0.100   8.104766
# ...

# %%
# sort values wrt mae
concatenated_0105_df.sort_values(['mae']).head()
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale      rmse       mae  \
# 34     0.100        0.5        0       0.500        0.100  8.104766  6.446527
# 25     0.100       -1.0        0       0.500        0.100  8.119741  6.456603
# 3      0.001       -1.0        0       0.100        0.001  8.177548  6.634099
# 28     0.100        0.5        0       0.001        0.100  8.868719  6.688457
# 0      0.001       -1.0        0       0.001        0.001  9.409783  6.715131
#
#         corr  avg_width_train  coverage_train
# 34  0.673383        23.862343        0.857143
# 25  0.672416        25.507446        0.857143
# 3   0.569040         3.952131        0.142857
# 28  0.619673        40.576245        0.857143
# 0   0.633133         5.619919        0.285714

# %%
# chosen parameters
# wrt width
# 0.001	0.5	0	0.001	0.001	9.410910	6.715907	0.633567	5.459152	0.285714
# 0.001	-1.0 0	0.001	0.001	9.409783	6.715131	0.633133	5.619919	0.285714
# wrt mae
# 0.100	0.5	0	0.500	0.100	8.104766	6.446527	0.673383	23.862343	0.857143
# 0.100	-1.0 0	0.500	0.100	8.119741	6.456603	0.672416	25.507446	0.857143

# %% [markdown]
# block 0104

# %%
path_0104 = "Store_metric_results/block_0104"

# %%
os.listdir(path_0104)
# Out:
# ['hpo_metrics_for_block0104_4.csv',
#  'hpo_metrics_for_block0104_3.csv',
#  'hpo_metrics_for_block0104_2.csv',
#  'hpo_metrics_for_block0104_5.csv',
#  '.ipynb_checkpoints',
#  'hpo_metrics_for_block0104_6.csv',
#  'hpo_metrics_for_block0104_1.csv',
#  'on_demand']

# %%
# get only the csv files
csv_0104 = [file for file in os.listdir(path_0104) if file.split(".")[-1] == 'csv']
csv_0104.sort()

# %%
csv_0104
# Out:
# ['hpo_metrics_for_block0104_1.csv',
#  'hpo_metrics_for_block0104_2.csv',
#  'hpo_metrics_for_block0104_3.csv',
#  'hpo_metrics_for_block0104_4.csv',
#  'hpo_metrics_for_block0104_5.csv',
#  'hpo_metrics_for_block0104_6.csv']

# %%
all_dfs_0104 = []
for csv in csv_0104:
    joined_path = os.path.join(path_0104, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0104.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0104_df = pd.concat(all_dfs_0104, axis = 0).reset_index(drop = True)

# %%
concatenated_0104_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   5.035687
# 1     0.001       -1.0        0       0.001        0.100  36.767825
# 2     0.001       -1.0        0       0.001        0.500  36.794481
# 3     0.001       -1.0        0       0.100        0.001   7.534485
# 4     0.001       -1.0        0       0.100        0.100  27.968381
#
#          mae      corr  avg_width_train  coverage_train
# 0   4.858796 -0.269368         4.872553        0.000000
# 1  36.446220  0.477417        14.683095        0.000000
# 2  36.454938 -0.793832        30.289743        0.000000
# 3   5.460121  0.140733         3.136511        0.285714
# 4  27.570481  0.294418        14.836672        0.000000

# %%
# sort values wrt width
concatenated_0104_df.sort_values(['avg_width_train']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001   7.350002
# 3      0.001       -1.0        0       0.100        0.001   7.534485
# 15     0.001        0.5        0       0.500        0.001  16.264160
# 9      0.001        0.5        0       0.001        0.001   5.036035
# 0      0.001       -1.0        0       0.001        0.001   5.035687
# 6      0.001       -1.0        0       0.500        0.001  12.482424
# 16     0.001        0.5        0       0.500        0.100   4.792824
# 7      0.001       -1.0        0       0.500        0.100   4.720268
# 1      0.001       -1.0        0       0.001        0.100  36.767825
# 10     0.001        0.5        0       0.001        0.100  36.784716
# 4      0.001       -1.0        0       0.100        0.100  27.968381
# 13     0.001        0.5        0       0.100        0.100  27.984446
# 25     0.100       -1.0        0       0.500        0.100   6.109503
# ...

# %%
# sort values wrt mae
concatenated_0104_df.sort_values(['mae']).head()
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale      rmse       mae  \
# 7      0.001       -1.0        0       0.500        0.100  4.720268  4.144832
# 16     0.001        0.5        0       0.500        0.100  4.792824  4.185402
# 0      0.001       -1.0        0       0.001        0.001  5.035687  4.858796
# 9      0.001        0.5        0       0.001        0.001  5.036035  4.858799
# 25     0.100       -1.0        0       0.500        0.100  6.109503  4.984141
#
#         corr  avg_width_train  coverage_train
# 7   0.763934        13.491876        0.857143
# 16  0.774718        12.133532        0.714286
# 0  -0.269368         4.872553        0.000000
# 9  -0.270314         4.871014        0.000000
# 25  0.083535        19.130015        1.000000

# %%
# chosen parameters
# 0.001	-1.0	0	0.500	0.100	4.720268	4.144832	0.763934	13.491876	0.857143

# %% [markdown]
# block 0106

# %%
path_0106 = "Store_metric_results/block_0106"

# %%
os.listdir(path_0106)
# Out:
# ['hpo_metrics_for_block0106_3.csv',
#  'hpo_metrics_for_block0106_4.csv',
#  'hpo_metrics_for_block0106_5.csv',
#  'hpo_metrics_for_block0106_2.csv',
#  'hpo_metrics_for_block0106_1.csv',
#  'hpo_metrics_for_block0106_6.csv']

# %%
# get only the csv files
csv_0106 = [file for file in os.listdir(path_0106) if file.split(".")[-1] == 'csv']
csv_0106.sort()

# %%
csv_0106
# Out:
# ['hpo_metrics_for_block0106_1.csv',
#  'hpo_metrics_for_block0106_2.csv',
#  'hpo_metrics_for_block0106_3.csv',
#  'hpo_metrics_for_block0106_4.csv',
#  'hpo_metrics_for_block0106_5.csv',
#  'hpo_metrics_for_block0106_6.csv']

# %%
all_dfs_0106 = []
for csv in csv_0106:
    joined_path = os.path.join(path_0106, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0106.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0106_df = pd.concat(all_dfs_0106, axis = 0).reset_index(drop = True)

# %%
concatenated_0106_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   7.288159
# 1     0.001       -1.0        0       0.001        0.100  41.859937
# 2     0.001       -1.0        0       0.001        0.500  41.848069
# 3     0.001       -1.0        0       0.100        0.001   5.727073
# 4     0.001       -1.0        0       0.100        0.100  33.649103
#
#          mae      corr  avg_width_train  coverage_train
# 0   6.223052 -0.283819         4.801864        0.000000
# 1  41.717685  0.136007        15.539965        0.000000
# 2  41.704184 -0.284551        32.580029        0.000000
# 3   3.776772 -0.745285         6.971679        0.714286
# 4  33.447567  0.024730        16.291585        0.000000

# %%
# sort values wrt width
concatenated_0106_df.sort_values(['avg_width_train']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001   4.785695
# 0      0.001       -1.0        0       0.001        0.001   7.288159
# 9      0.001        0.5        0       0.001        0.001   7.290466
# 15     0.001        0.5        0       0.500        0.001  26.620793
# 3      0.001       -1.0        0       0.100        0.001   5.727073
# 6      0.001       -1.0        0       0.500        0.001  30.549269
# 1      0.001       -1.0        0       0.001        0.100  41.859937
# 10     0.001        0.5        0       0.001        0.100  41.807397
# 13     0.001        0.5        0       0.100        0.100  33.641302
# 4      0.001       -1.0        0       0.100        0.100  33.649103
# 16     0.001        0.5        0       0.500        0.100   4.916649
# 7      0.001       -1.0        0       0.500        0.100   5.100591
# 25     0.100       -1.0        0       0.500        0.100   6.473670
# ...

# %%
# sort values wrt mae
concatenated_0106_df.sort_values(['mae']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 35     0.100        0.5        0       0.500        0.500   5.363232
# 12     0.001        0.5        0       0.100        0.001   4.785695
# 3      0.001       -1.0        0       0.100        0.001   5.727073
# 26     0.100       -1.0        0       0.500        0.500   5.727115
# 16     0.001        0.5        0       0.500        0.100   4.916649
# 7      0.001       -1.0        0       0.500        0.100   5.100591
# 25     0.100       -1.0        0       0.500        0.100   6.473670
# 34     0.100        0.5        0       0.500        0.100   6.652695
# 0      0.001       -1.0        0       0.001        0.001   7.288159
# 9      0.001        0.5        0       0.001        0.001   7.290466
# 23     0.100       -1.0        0       0.100        0.500   8.074435
# 32     0.100        0.5        0       0.100        0.500   8.117627
# 24     0.100       -1.0        0       0.500        0.001   9.408163
# ...

# %%
# chosen parameters - note the correlations are all bad
# wrt width
# 0.001	0.5	0	0.500	0.100	4.916649	4.370984	-0.282061	16.637327	0.857143
# 0.001	-1.0 0	0.500	0.100	5.100591	4.556550	-0.285118	18.060349	0.857143
# wrt mae
# same as above with average width

# %% [markdown]
# block 0201

# %%
path_0201 = "Store_metric_results/block_0201"

# %%
os.listdir(path_0201)
# Out:
# ['hpo_metrics_for_block0201_1.csv',
#  'hpo_metrics_for_block0201_6.csv',
#  'hpo_metrics_for_block0201_5.csv',
#  'hpo_metrics_for_block0201_2.csv',
#  'hpo_metrics_for_block0201_3.csv',
#  'hpo_metrics_for_block0201_4.csv']

# %%
# get only the csv files
csv_0201 = [file for file in os.listdir(path_0201) if file.split(".")[-1] == 'csv']
csv_0201.sort()

# %%
csv_0201
# Out:
# ['hpo_metrics_for_block0201_1.csv',
#  'hpo_metrics_for_block0201_2.csv',
#  'hpo_metrics_for_block0201_3.csv',
#  'hpo_metrics_for_block0201_4.csv',
#  'hpo_metrics_for_block0201_5.csv',
#  'hpo_metrics_for_block0201_6.csv']

# %%
all_dfs_0201 = []
for csv in csv_0201:
    joined_path = os.path.join(path_0201, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0201.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0201_df = pd.concat(all_dfs_0201, axis = 0).reset_index(drop = True)

# %%
concatenated_0201_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   5.146352
# 1     0.001       -1.0        0       0.001        0.100  40.615078
# 2     0.001       -1.0        0       0.001        0.500  40.672434
# 3     0.001       -1.0        0       0.100        0.001   5.285723
# 4     0.001       -1.0        0       0.100        0.100  34.302517
#
#          mae      corr  avg_width_train  coverage_train
# 0   4.522033  0.857552         4.080627        0.142857
# 1  40.164594 -0.278214        17.372828        0.000000
# 2  40.224464 -0.125815        36.923689        0.000000
# 3   4.304272  0.736253         6.617347        0.285714
# 4  33.618398 -0.664555        17.109623        0.000000

# %%
# sort values wrt width
concatenated_0201_df.sort_values(['avg_width_train']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001   6.554886
# 15     0.001        0.5        0       0.500        0.001  10.290565
# 9      0.001        0.5        0       0.001        0.001   5.158595
# 0      0.001       -1.0        0       0.001        0.001   5.146352
# 6      0.001       -1.0        0       0.500        0.001  10.216197
# 3      0.001       -1.0        0       0.100        0.001   5.285723
# 16     0.001        0.5        0       0.500        0.100   9.560204
# 7      0.001       -1.0        0       0.500        0.100   9.593139
# 4      0.001       -1.0        0       0.100        0.100  34.302517
# 13     0.001        0.5        0       0.100        0.100  34.276144
# 10     0.001        0.5        0       0.001        0.100  40.553400
# 1      0.001       -1.0        0       0.001        0.100  40.615078
# 25     0.100       -1.0        0       0.500        0.100   6.219187
# ...

# %%
# sort values wrt mae
concatenated_0201_df.sort_values(['mae']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale      rmse       mae  \
# 29     0.100        0.5        0       0.001        0.500  5.112146  4.222757
# 3      0.001       -1.0        0       0.100        0.001  5.285723  4.304272
# 20     0.100       -1.0        0       0.001        0.500  5.044912  4.431793
# 32     0.100        0.5        0       0.100        0.500  5.427854  4.475313
# 35     0.100        0.5        0       0.500        0.500  6.008921  4.518552
# 0      0.001       -1.0        0       0.001        0.001  5.146352  4.522033
# 9      0.001        0.5        0       0.001        0.001  5.158595  4.532924
# 31     0.100        0.5        0       0.100        0.100  5.367548  4.679895
# 19     0.100       -1.0        0       0.001        0.100  5.442188  4.730305
# 26     0.100       -1.0        0       0.500        0.500  6.146540  4.731500
# 23     0.100       -1.0        0       0.100        0.500  5.345513  4.735309
# ...

# %%
# chosen parameters - note the correlations are all bad
# wrt width
# 0.100	-1.0	0	0.500	0.100	6.219187	5.114849	0.817592	22.864412	1.000000
# wrt mae
# 0.100	0.5	0	0.001	0.500	5.112146	4.222757	0.842643	44.050206	1.000000

# %% [markdown]
# block 0202

# %%
path_0202 = "Store_metric_results/block_0202"

# %%
os.listdir(path_0202)
# Out:
# ['hpo_metrics_for_block0202_3.csv',
#  'hpo_metrics_for_block0202_4.csv',
#  'hpo_metrics_for_block0202_5.csv',
#  'hpo_metrics_for_block0202_2.csv',
#  'hpo_metrics_for_block0202_1.csv',
#  'hpo_metrics_for_block0202_6.csv']

# %%
# get only the csv files
csv_0202 = [file for file in os.listdir(path_0202) if file.split(".")[-1] == 'csv']
csv_0202.sort()

# %%
csv_0202
# Out:
# ['hpo_metrics_for_block0202_1.csv',
#  'hpo_metrics_for_block0202_2.csv',
#  'hpo_metrics_for_block0202_3.csv',
#  'hpo_metrics_for_block0202_4.csv',
#  'hpo_metrics_for_block0202_5.csv',
#  'hpo_metrics_for_block0202_6.csv']

# %%
all_dfs_0202 = []
for csv in csv_0202:
    joined_path = os.path.join(path_0202, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0202.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0202_df = pd.concat(all_dfs_0202, axis = 0).reset_index(drop = True)

# %%
concatenated_0202_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   2.958697
# 1     0.001       -1.0        0       0.001        0.100  20.063368
# 2     0.001       -1.0        0       0.001        0.500  20.127553
# 3     0.001       -1.0        0       0.100        0.001   1.855982
# 4     0.001       -1.0        0       0.100        0.100  13.262926
#
#          mae      corr  avg_width_train  coverage_train
# 0   2.628089  0.234035         3.149822        0.285714
# 1  19.979336  0.362808        12.348843        0.000000
# 2  20.042153  0.014933        25.119284        0.000000
# 3   1.753119  0.139368         2.307526        0.142857
# 4  12.988727 -0.138743        12.315074        0.000000

# %%
# sort values wrt width
concatenated_0202_df.sort_values(['avg_width_train']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001   2.118313
# 15     0.001        0.5        0       0.500        0.001   2.866503
# 6      0.001       -1.0        0       0.500        0.001   2.915013
# 3      0.001       -1.0        0       0.100        0.001   1.855982
# 0      0.001       -1.0        0       0.001        0.001   2.958697
# 9      0.001        0.5        0       0.001        0.001   2.957118
# 7      0.001       -1.0        0       0.500        0.100   3.884695
# 16     0.001        0.5        0       0.500        0.100   3.810519
# 10     0.001        0.5        0       0.001        0.100  20.070728
# 4      0.001       -1.0        0       0.100        0.100  13.262926
# 13     0.001        0.5        0       0.100        0.100  13.274644
# 1      0.001       -1.0        0       0.001        0.100  20.063368
# 34     0.100        0.5        0       0.500        0.100   1.922280
# ...

# %%
# sort values wrt mae
concatenated_0202_df.sort_values(['mae']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale      rmse       mae  \
# 34     0.100        0.5        0       0.500        0.100  1.922280  1.639836
# 25     0.100       -1.0        0       0.500        0.100  2.074492  1.711932
# 3      0.001       -1.0        0       0.100        0.001  1.855982  1.753119
# 12     0.001        0.5        0       0.100        0.001  2.118313  1.795204
# 6      0.001       -1.0        0       0.500        0.001  2.915013  2.555256
# 9      0.001        0.5        0       0.001        0.001  2.957118  2.626549
# 0      0.001       -1.0        0       0.001        0.001  2.958697  2.628089
# 15     0.001        0.5        0       0.500        0.001  2.866503  2.687665
# 35     0.100        0.5        0       0.500        0.500  3.515046  3.196165
# 43     0.500       -1.0        0       0.500        0.100  3.423513  3.215367
# 44     0.500       -1.0        0       0.500        0.500  3.570817  3.251380
# ...

# %%
# chosen parameters - note the correlations are all bad
# wrt width
# 0.001	-1.0	0	0.500	0.100	3.884695	3.408631	0.278659	9.038943	0.571429
# wrt mae
# 0.001	0.5	0	0.500	0.100	3.810519	3.344038	0.303610	9.303410	0.571429

# %% [markdown]
# block 0205

# %%
path_0205 = "Store_metric_results/block_0205"

# %%
os.listdir(path_0205)
# Out:
# ['hpo_metrics_for_block0205_2.csv',
#  'hpo_metrics_for_block0205_5.csv',
#  'hpo_metrics_for_block0205_4.csv',
#  'hpo_metrics_for_block0205_3.csv',
#  'hpo_metrics_for_block0205_6.csv',
#  'hpo_metrics_for_block0205_1.csv']

# %%
# get only the csv files
csv_0205 = [file for file in os.listdir(path_0205) if file.split(".")[-1] == 'csv']
csv_0205.sort()

# %%
csv_0205
# Out:
# ['hpo_metrics_for_block0205_1.csv',
#  'hpo_metrics_for_block0205_2.csv',
#  'hpo_metrics_for_block0205_3.csv',
#  'hpo_metrics_for_block0205_4.csv',
#  'hpo_metrics_for_block0205_5.csv',
#  'hpo_metrics_for_block0205_6.csv']

# %%
all_dfs_0205 = []
for csv in csv_0205:
    joined_path = os.path.join(path_0205, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0205.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0205_df = pd.concat(all_dfs_0205, axis = 0).reset_index(drop = True)

# %%
concatenated_0205_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   3.567765
# 1     0.001       -1.0        0       0.001        0.100  41.067704
# 2     0.001       -1.0        0       0.001        0.500  41.074406
# 3     0.001       -1.0        0       0.100        0.001   5.022935
# 4     0.001       -1.0        0       0.100        0.100  34.408885
#
#          mae      corr  avg_width_train  coverage_train
# 0   2.967848  0.764558         5.194658        0.428571
# 1  40.864426 -0.665746        16.275332        0.000000
# 2  40.867553 -0.436444        34.179784        0.000000
# 3   3.748664  0.327872         6.173483        0.571429
# 4  34.070290 -0.441537        16.751646        0.000000

# %%
# sort values wrt width
concatenated_0205_df.sort_values(['avg_width_train']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001   5.155157
# 9      0.001        0.5        0       0.001        0.001   3.568620
# 0      0.001       -1.0        0       0.001        0.001   3.567765
# 3      0.001       -1.0        0       0.100        0.001   5.022935
# 15     0.001        0.5        0       0.500        0.001  22.558448
# 6      0.001       -1.0        0       0.500        0.001  23.962656
# 10     0.001        0.5        0       0.001        0.100  41.038182
# 1      0.001       -1.0        0       0.001        0.100  41.067704
# 4      0.001       -1.0        0       0.100        0.100  34.408885
# 13     0.001        0.5        0       0.100        0.100  34.395402
# 7      0.001       -1.0        0       0.500        0.100   6.741101
# 16     0.001        0.5        0       0.500        0.100   6.096519
# 25     0.100       -1.0        0       0.500        0.100   3.657805
# ...

# %%
# sort values wrt mae
concatenated_0205_df.sort_values(['mae']).head(15)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale      rmse       mae  \
# 0      0.001       -1.0        0       0.001        0.001  3.567765  2.967848
# 9      0.001        0.5        0       0.001        0.001  3.568620  2.968826
# 25     0.100       -1.0        0       0.500        0.100  3.657805  3.130698
# 34     0.100        0.5        0       0.500        0.100  3.797009  3.315057
# 35     0.100        0.5        0       0.500        0.500  4.300192  3.729084
# 3      0.001       -1.0        0       0.100        0.001  5.022935  3.748664
# 26     0.100       -1.0        0       0.500        0.500  4.568967  3.980703
# 12     0.001        0.5        0       0.100        0.001  5.155157  3.993332
# 16     0.001        0.5        0       0.500        0.100  6.096519  5.013918
# 28     0.100        0.5        0       0.001        0.100  6.135917  5.493854
# 19     0.100       -1.0        0       0.001        0.100  6.207944  5.565623
# ...

# %%
# chosen parameters - note the correlations are all bad
# wrt width
# 0.001	0.5	0	0.001	0.001	3.568620	2.968826	0.764806	5.191591	0.428571
# wrt mae
# 0.001	-1.0	0	0.001	0.001	3.567765	2.967848	0.764558	5.194658	0.428571

# %% [markdown]
# block 0206

# %%
path_0206 = "Store_metric_results/block_0206"

# %%
os.listdir(path_0206)
# Out:
# ['hpo_metrics_for_block0206_5.csv',
#  'hpo_metrics_for_block0206_2.csv',
#  'hpo_metrics_for_block0206_3.csv',
#  'hpo_metrics_for_block0206_4.csv',
#  'hpo_metrics_for_block0206_1.csv',
#  'hpo_metrics_for_block0206_6.csv']

# %%
# get only the csv files
csv_0206 = [file for file in os.listdir(path_0206) if file.split(".")[-1] == 'csv']
csv_0206.sort()

# %%
csv_0206
# Out:
# ['hpo_metrics_for_block0206_1.csv',
#  'hpo_metrics_for_block0206_2.csv',
#  'hpo_metrics_for_block0206_3.csv',
#  'hpo_metrics_for_block0206_4.csv',
#  'hpo_metrics_for_block0206_5.csv',
#  'hpo_metrics_for_block0206_6.csv']

# %%
all_dfs_0206 = []
for csv in csv_0206:
    joined_path = os.path.join(path_0206, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0206.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0206_df = pd.concat(all_dfs_0206, axis = 0).reset_index(drop = True)

# %%
concatenated_0206_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001  11.440046
# 1     0.001       -1.0        0       0.001        0.100  32.665216
# 2     0.001       -1.0        0       0.001        0.500  32.643423
# 3     0.001       -1.0        0       0.100        0.001  15.356018
# 4     0.001       -1.0        0       0.100        0.100  25.537609
#
#          mae      corr  avg_width_train  coverage_train
# 0   8.776549  0.892551         4.451087        0.142857
# 1  31.441579  0.802967        15.149075        0.000000
# 2  31.407126 -0.032281        31.958715        0.000000
# 3  11.690137 -0.916006         2.324077        0.285714
# 4  23.202300 -0.823287        14.841684        0.000000

# %%
# sort values wrt width
concatenated_0206_df.sort_values(['avg_width_train']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001  15.157998
# 15     0.001        0.5        0       0.500        0.001  15.625524
# 6      0.001       -1.0        0       0.500        0.001  13.816506
# 3      0.001       -1.0        0       0.100        0.001  15.356018
# 9      0.001        0.5        0       0.001        0.001  11.513781
# 0      0.001       -1.0        0       0.001        0.001  11.440046
# 16     0.001        0.5        0       0.500        0.100  18.006953
# 7      0.001       -1.0        0       0.500        0.100  17.955512
# 13     0.001        0.5        0       0.100        0.100  25.598510
# 4      0.001       -1.0        0       0.100        0.100  25.537609
# 10     0.001        0.5        0       0.001        0.100  32.653323
# 1      0.001       -1.0        0       0.001        0.100  32.665216
# 25     0.100       -1.0        0       0.500        0.100  13.204654
# ...

# %%
# sort values wrt mae
concatenated_0206_df.sort_values(['mae']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale      rmse       mae  \
# 37       0.5       -1.0        0       0.001        0.100  5.645921  4.804230
# 46       0.5        0.5        0       0.001        0.100  5.840521  4.856045
# 36       0.5       -1.0        0       0.001        0.001  6.144675  4.889573
# 40       0.5       -1.0        0       0.100        0.100  5.715273  4.909162
# 49       0.5        0.5        0       0.100        0.100  6.166993  4.925120
# 47       0.5        0.5        0       0.001        0.500  5.496959  5.027605
# 38       0.5       -1.0        0       0.001        0.500  5.591429  5.117298
# 45       0.5        0.5        0       0.001        0.001  6.278371  5.118990
# 27       0.1        0.5        0       0.001        0.001  5.593405  5.141129
# 50       0.5        0.5        0       0.100        0.500  5.655475  5.198793
# 41       0.5       -1.0        0       0.100        0.500  5.670198  5.231393
# ...

# %%
# chosen parameters - note the correlations are all bad
# wrt width
# 0.001	-1.0	0	0.001	0.001	11.440046	8.776549	0.892551	4.451087	0.142857
# wrt mae
# 0.1	0.5	0	0.100	0.100	7.998264	6.930218	0.950048	29.367633	1.0

# %% [markdown]
# block 0302

# %%
path_0302 = "Store_metric_results/block_0302"

# %%
os.listdir(path_0302)
# Out:
# ['hpo_metrics_for_block0302_2.csv',
#  'hpo_metrics_for_block0302_5.csv',
#  'hpo_metrics_for_block0302_4.csv',
#  'hpo_metrics_for_block0302_3.csv',
#  'hpo_metrics_for_block0302_6.csv',
#  'hpo_metrics_for_block0302_1.csv']

# %%
# get only the csv files
csv_0302 = [file for file in os.listdir(path_0302) if file.split(".")[-1] == 'csv']
csv_0302.sort()

# %%
csv_0302
# Out:
# ['hpo_metrics_for_block0302_1.csv',
#  'hpo_metrics_for_block0302_2.csv',
#  'hpo_metrics_for_block0302_3.csv',
#  'hpo_metrics_for_block0302_4.csv',
#  'hpo_metrics_for_block0302_5.csv',
#  'hpo_metrics_for_block0302_6.csv']

# %%
all_dfs_0302 = []
for csv in csv_0302:
    joined_path = os.path.join(path_0302, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0302.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0302_df = pd.concat(all_dfs_0302, axis = 0).reset_index(drop = True)

# %%
concatenated_0302_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   4.593309
# 1     0.001       -1.0        0       0.001        0.100  47.384479
# 2     0.001       -1.0        0       0.001        0.500  47.361124
# 3     0.001       -1.0        0       0.100        0.001   7.979448
# 4     0.001       -1.0        0       0.100        0.100  42.120763
#
#          mae      corr  avg_width_train  coverage_train
# 0   3.813276  0.742319         5.034726        0.428571
# 1  47.109050  0.278212        16.993095        0.000000
# 2  47.082410 -0.143484        36.249120        0.000000
# 3   6.495311 -0.194972         2.670281        0.142857
# 4  41.750085 -0.569225        17.033866        0.000000

# %%
# sort values wrt width
concatenated_0302_df.sort_values(['avg_width_train']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 3      0.001       -1.0        0       0.100        0.001   7.979448
# 12     0.001        0.5        0       0.100        0.001   7.745424
# 9      0.001        0.5        0       0.001        0.001   4.643791
# 15     0.001        0.5        0       0.500        0.001  22.434278
# 0      0.001       -1.0        0       0.001        0.001   4.593309
# 6      0.001       -1.0        0       0.500        0.001  17.777640
# 7      0.001       -1.0        0       0.500        0.100   9.614081
# 16     0.001        0.5        0       0.500        0.100   9.696776
# 1      0.001       -1.0        0       0.001        0.100  47.384479
# 4      0.001       -1.0        0       0.100        0.100  42.120763
# 13     0.001        0.5        0       0.100        0.100  42.169607
# 10     0.001        0.5        0       0.001        0.100  47.440023
# 34     0.100        0.5        0       0.500        0.100   5.350306
# ...

# %%
# sort values wrt mae
concatenated_0302_df.sort_values(['mae']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 9      0.001        0.5        0       0.001        0.001   4.643791
# 0      0.001       -1.0        0       0.001        0.001   4.593309
# 25     0.100       -1.0        0       0.500        0.100   5.370625
# 34     0.100        0.5        0       0.500        0.100   5.350306
# 22     0.100       -1.0        0       0.100        0.100   6.398493
# 28     0.100        0.5        0       0.001        0.100   6.573464
# 31     0.100        0.5        0       0.100        0.100   6.574314
# 19     0.100       -1.0        0       0.001        0.100   6.645211
# 35     0.100        0.5        0       0.500        0.500   6.321602
# 12     0.001        0.5        0       0.100        0.001   7.745424
# 26     0.100       -1.0        0       0.500        0.500   6.595069
# 32     0.100        0.5        0       0.100        0.500   7.125029
# 3      0.001       -1.0        0       0.100        0.001   7.979448
# ...

# %%
# chosen parameters - note the correlations are all bad
# wrt width
# 0.001	0.5	0	0.001	0.001	4.643791	3.762106	0.681344	4.165172	0.428571
# wrt mae
# 0.100	0.5	0	0.500	0.100	5.350306	4.692833	0.414410	23.414976	1.000000

# %% [markdown]
# block 0303

# %%
path_0303 = "Store_metric_results/block_0303"

# %%
os.listdir(path_0303)
# Out:
# ['hpo_metrics_for_block0303_6.csv',
#  'hpo_metrics_for_block0303_1.csv',
#  'hpo_metrics_for_block0303_2.csv',
#  'hpo_metrics_for_block0303_5.csv',
#  'hpo_metrics_for_block0303_4.csv',
#  'hpo_metrics_for_block0303_3.csv']

# %%
# get only the csv files
csv_0303 = [file for file in os.listdir(path_0303) if file.split(".")[-1] == 'csv']
csv_0303.sort()

# %%
csv_0303
# Out:
# ['hpo_metrics_for_block0303_1.csv',
#  'hpo_metrics_for_block0303_2.csv',
#  'hpo_metrics_for_block0303_3.csv',
#  'hpo_metrics_for_block0303_4.csv',
#  'hpo_metrics_for_block0303_5.csv',
#  'hpo_metrics_for_block0303_6.csv']

# %%
all_dfs_0303 = []
for csv in csv_0303:
    joined_path = os.path.join(path_0303, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0303.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0303_df = pd.concat(all_dfs_0303, axis = 0).reset_index(drop = True)

# %%
concatenated_0303_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   7.833542
# 1     0.001       -1.0        0       0.001        0.100  39.638134
# 2     0.001       -1.0        0       0.001        0.500  39.711994
# 3     0.001       -1.0        0       0.100        0.001  17.953861
# 4     0.001       -1.0        0       0.100        0.100  33.855637
#
#          mae      corr  avg_width_train  coverage_train
# 0   5.897452  0.942921         4.085479        0.142857
# 1  38.844849  0.371941        16.181792        0.000000
# 2  38.908559 -0.375928        33.607215        0.000000
# 3  13.903642 -0.800472         3.339808        0.142857
# 4  32.764957 -0.688450        15.941782        0.000000

# %%
# sort values wrt width
concatenated_0303_df.sort_values(['avg_width_train']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001  18.596683
# 3      0.001       -1.0        0       0.100        0.001  17.953861
# 15     0.001        0.5        0       0.500        0.001  28.167560
# 0      0.001       -1.0        0       0.001        0.001   7.833542
# 9      0.001        0.5        0       0.001        0.001   7.824670
# 6      0.001       -1.0        0       0.500        0.001  25.503396
# 16     0.001        0.5        0       0.500        0.100  15.202866
# 7      0.001       -1.0        0       0.500        0.100  15.291890
# 13     0.001        0.5        0       0.100        0.100  33.837933
# 4      0.001       -1.0        0       0.100        0.100  33.855637
# 1      0.001       -1.0        0       0.001        0.100  39.638134
# 10     0.001        0.5        0       0.001        0.100  39.659587
# 34     0.100        0.5        0       0.500        0.100   9.851179
# ...

# %%
# sort values wrt mae
concatenated_0303_df.sort_values(['mae']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale      rmse       mae  \
# 31     0.100        0.5        0       0.100        0.100  5.728206  4.299652
# 28     0.100        0.5        0       0.001        0.100  5.686542  4.363908
# 22     0.100       -1.0        0       0.100        0.100  5.757038  4.397182
# 19     0.100       -1.0        0       0.001        0.100  5.817702  4.539265
# 44     0.500       -1.0        0       0.500        0.500  6.151814  5.445827
# 53     0.500        0.5        0       0.500        0.500  6.332214  5.765952
# 18     0.100       -1.0        0       0.001        0.001  6.035452  5.800517
# 27     0.100        0.5        0       0.001        0.001  5.989475  5.803380
# 9      0.001        0.5        0       0.001        0.001  7.824670  5.890596
# 0      0.001       -1.0        0       0.001        0.001  7.833542  5.897452
# 32     0.100        0.5        0       0.100        0.500  7.456365  5.964269
# ...

# %%
# chosen parameters - note the correlations are all bad
# wrt width
# 0.001	-1.0	0	0.001	0.001	7.833542	5.897452	0.942921	4.085479	0.142857
# wrt mae
# 0.100	-1.0	0	0.100	0.100	5.757038	4.397182	0.912355	28.146008	1.000000

# %% [markdown]
# block 0304

# %%
path_0304 = "Store_metric_results/block_0304"

# %%
os.listdir(path_0304)
# Out:
# ['hpo_metrics_for_block0304_6.csv',
#  'hpo_metrics_for_block0304_1.csv',
#  'hpo_metrics_for_block0304_2.csv',
#  'hpo_metrics_for_block0304_5.csv',
#  'hpo_metrics_for_block0304_4.csv',
#  'hpo_metrics_for_block0304_3.csv']

# %%
# get only the csv files
csv_0304 = [file for file in os.listdir(path_0304) if file.split(".")[-1] == 'csv']
csv_0304.sort()

# %%
csv_0304
# Out:
# ['hpo_metrics_for_block0304_1.csv',
#  'hpo_metrics_for_block0304_2.csv',
#  'hpo_metrics_for_block0304_3.csv',
#  'hpo_metrics_for_block0304_4.csv',
#  'hpo_metrics_for_block0304_5.csv',
#  'hpo_metrics_for_block0304_6.csv']

# %%
all_dfs_0304 = []
for csv in csv_0304:
    joined_path = os.path.join(path_0304, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0304.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0304_df = pd.concat(all_dfs_0304, axis = 0).reset_index(drop = True)

# %%
concatenated_0304_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   6.866949
# 1     0.001       -1.0        0       0.001        0.100  37.532177
# 2     0.001       -1.0        0       0.001        0.500  37.464670
# 3     0.001       -1.0        0       0.100        0.001   5.375066
# 4     0.001       -1.0        0       0.100        0.100  31.131864
#
#          mae      corr  avg_width_train  coverage_train
# 0   4.741181  0.732136         4.662638        0.571429
# 1  37.040983 -0.102610        16.023814        0.000000
# 2  36.982368  0.304877        33.651707        0.000000
# 3   3.685682  0.783274         3.022345        0.428571
# 4  30.408835 -0.281514        15.494386        0.000000

# %%
# sort values wrt width
concatenated_0304_df.sort_values(['avg_width_train']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001   4.045283
# 3      0.001       -1.0        0       0.100        0.001   5.375066
# 9      0.001        0.5        0       0.001        0.001   7.040395
# 0      0.001       -1.0        0       0.001        0.001   6.866949
# 15     0.001        0.5        0       0.500        0.001  29.554247
# 6      0.001       -1.0        0       0.500        0.001  27.427688
# 7      0.001       -1.0        0       0.500        0.100   9.227005
# 16     0.001        0.5        0       0.500        0.100   9.196263
# 13     0.001        0.5        0       0.100        0.100  31.223157
# 4      0.001       -1.0        0       0.100        0.100  31.131864
# 10     0.001        0.5        0       0.001        0.100  37.527420
# 1      0.001       -1.0        0       0.001        0.100  37.532177
# 25     0.100       -1.0        0       0.500        0.100   4.285113
# ...

# %%
# sort values wrt mae
concatenated_0304_df.sort_values(['mae']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale      rmse       mae  \
# 25     0.100       -1.0        0       0.500        0.100  4.285113  3.203975
# 12     0.001        0.5        0       0.100        0.001  4.045283  3.213117
# 34     0.100        0.5        0       0.500        0.100  4.234189  3.636215
# 3      0.001       -1.0        0       0.100        0.001  5.375066  3.685682
# 28     0.100        0.5        0       0.001        0.100  4.852746  4.029097
# 19     0.100       -1.0        0       0.001        0.100  4.853579  4.050438
# 31     0.100        0.5        0       0.100        0.100  4.862425  4.069886
# 22     0.100       -1.0        0       0.100        0.100  4.893703  4.081290
# 29     0.100        0.5        0       0.001        0.500  5.428341  4.408533
# 32     0.100        0.5        0       0.100        0.500  5.595394  4.476022
# 0      0.001       -1.0        0       0.001        0.001  6.866949  4.741181
# ...

# %%
# chosen parameters - note the correlations are all bad
# wrt width
# 0.001	-1.0	0	0.001	0.001	6.866949	4.741181	0.732136	4.662638	0.571429
# wrt mae
# 0.100	-1.0	0	0.500	0.100	4.285113	3.203975	0.855945	24.092025	1.000000

# %% [markdown]
# block 0305

# %%
path_0305 = "Store_metric_results/block_0305"

# %%
os.listdir(path_0305)
# Out:
# ['hpo_metrics_for_block0305_5.csv',
#  'hpo_metrics_for_block0305_2.csv',
#  'hpo_metrics_for_block0305_3.csv',
#  'hpo_metrics_for_block0305_4.csv',
#  'hpo_metrics_for_block0305_1.csv',
#  'hpo_metrics_for_block0305_6.csv']

# %%
# get only the csv files
csv_0305 = [file for file in os.listdir(path_0305) if file.split(".")[-1] == 'csv']
csv_0305.sort()

# %%
csv_0305
# Out:
# ['hpo_metrics_for_block0305_1.csv',
#  'hpo_metrics_for_block0305_2.csv',
#  'hpo_metrics_for_block0305_3.csv',
#  'hpo_metrics_for_block0305_4.csv',
#  'hpo_metrics_for_block0305_5.csv',
#  'hpo_metrics_for_block0305_6.csv']

# %%
all_dfs_0305 = []
for csv in csv_0305:
    joined_path = os.path.join(path_0305, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0305.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0305_df = pd.concat(all_dfs_0305, axis = 0).reset_index(drop = True)

# %%
concatenated_0305_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   8.416194
# 1     0.001       -1.0        0       0.001        0.100  33.956609
# 2     0.001       -1.0        0       0.001        0.500  33.993249
# 3     0.001       -1.0        0       0.100        0.001   9.823917
# 4     0.001       -1.0        0       0.100        0.100  25.366631
#
#          mae      corr  avg_width_train  coverage_train
# 0   6.993426  0.881144         4.432768        0.142857
# 1  33.126782 -0.458034        16.060178        0.000000
# 2  33.175490  0.126918        33.684508        0.000000
# 3   8.323223  0.469078         3.378147        0.000000
# 4  24.165153 -0.133946        15.462135        0.000000

# %%
# sort values wrt width
concatenated_0305_df.sort_values(['avg_width_train']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001   9.632665
# 15     0.001        0.5        0       0.500        0.001   7.776378
# 6      0.001       -1.0        0       0.500        0.001   8.365734
# 3      0.001       -1.0        0       0.100        0.001   9.823917
# 0      0.001       -1.0        0       0.001        0.001   8.416194
# 9      0.001        0.5        0       0.001        0.001   8.417347
# 7      0.001       -1.0        0       0.500        0.100  10.725285
# 16     0.001        0.5        0       0.500        0.100  10.736237
# 4      0.001       -1.0        0       0.100        0.100  25.366631
# 13     0.001        0.5        0       0.100        0.100  25.355165
# 1      0.001       -1.0        0       0.001        0.100  33.956609
# 10     0.001        0.5        0       0.001        0.100  34.013100
# 25     0.100       -1.0        0       0.500        0.100   5.999323
# ...

# %%
# sort values wrt mae
concatenated_0305_df.sort_values(['mae']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale      rmse       mae  \
# 19       0.1       -1.0        0       0.001        0.100  5.364310  4.312992
# 28       0.1        0.5        0       0.001        0.100  5.351371  4.341340
# 31       0.1        0.5        0       0.100        0.100  5.383579  4.352064
# 22       0.1       -1.0        0       0.100        0.100  5.445804  4.389384
# 27       0.1        0.5        0       0.001        0.001  5.306338  4.411063
# 34       0.1        0.5        0       0.500        0.100  5.926049  4.456831
# 25       0.1       -1.0        0       0.500        0.100  5.999323  4.466782
# 18       0.1       -1.0        0       0.001        0.001  5.416745  4.516353
# 47       0.5        0.5        0       0.001        0.500  5.403071  4.552386
# 44       0.5       -1.0        0       0.500        0.500  5.683848  4.714618
# 53       0.5        0.5        0       0.500        0.500  5.689799  4.793842
# ...

# %%
# chosen parameters - note the correlations are all bad
# wrt width
# 0.001	-1.0	0	0.001	0.001	8.416194	6.993426	0.881144	4.432768	0.142857
# wrt mae
# 0.1	0.5	0	0.500	0.100	5.926049	4.456831	0.790796	22.595743	0.857143

# %% [markdown]
# block 0306

# %%
path_0306 = "Store_metric_results/block_0306"

# %%
os.listdir(path_0306)
# Out:
# ['hpo_metrics_for_block0306_6.csv',
#  'hpo_metrics_for_block0306_1.csv',
#  'hpo_metrics_for_block0306_2.csv',
#  'hpo_metrics_for_block0306_5.csv',
#  'hpo_metrics_for_block0306_4.csv',
#  'hpo_metrics_for_block0306_3.csv']

# %%
# get only the csv files
csv_0306 = [file for file in os.listdir(path_0306) if file.split(".")[-1] == 'csv']
csv_0306.sort()

# %%
csv_0306
# Out:
# ['hpo_metrics_for_block0306_1.csv',
#  'hpo_metrics_for_block0306_2.csv',
#  'hpo_metrics_for_block0306_3.csv',
#  'hpo_metrics_for_block0306_4.csv',
#  'hpo_metrics_for_block0306_5.csv',
#  'hpo_metrics_for_block0306_6.csv']

# %%
all_dfs_0306 = []
for csv in csv_0306:
    joined_path = os.path.join(path_0306, csv)
    read_file = pd.read_csv(joined_path)
    all_dfs_0306.append(read_file)

# %%
# concatenate all these files in the list
concatenated_0306_df = pd.concat(all_dfs_0306, axis = 0).reset_index(drop = True)

# %%
concatenated_0306_df.head()
# Out:
#    ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 0     0.001       -1.0        0       0.001        0.001   7.458316
# 1     0.001       -1.0        0       0.001        0.100  37.439347
# 2     0.001       -1.0        0       0.001        0.500  37.389407
# 3     0.001       -1.0        0       0.100        0.001  10.667254
# 4     0.001       -1.0        0       0.100        0.100  28.812880
#
#          mae      corr  avg_width_train  coverage_train
# 0   5.903400  0.760579         5.213468        0.142857
# 1  36.546621 -0.131757        16.057269        0.000000
# 2  36.513733  0.425180        33.222862        0.000000
# 3   6.600555 -0.541663         3.996977        0.428571
# 4  27.504955 -0.127180        15.744698        0.000000

# %%
# sort values wrt width
concatenated_0306_df.sort_values(['avg_width_train']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 12     0.001        0.5        0       0.100        0.001  11.527423
# 15     0.001        0.5        0       0.500        0.001   8.240316
# 3      0.001       -1.0        0       0.100        0.001  10.667254
# 0      0.001       -1.0        0       0.001        0.001   7.458316
# 9      0.001        0.5        0       0.001        0.001   7.455602
# 6      0.001       -1.0        0       0.500        0.001   7.846904
# 16     0.001        0.5        0       0.500        0.100  12.092175
# 7      0.001       -1.0        0       0.500        0.100  12.148065
# 4      0.001       -1.0        0       0.100        0.100  28.812880
# 10     0.001        0.5        0       0.001        0.100  37.476184
# 1      0.001       -1.0        0       0.001        0.100  37.439347
# 13     0.001        0.5        0       0.100        0.100  28.791645
# 25     0.100       -1.0        0       0.500        0.100   8.249109
# ...

# %%
# sort values wrt mae
concatenated_0306_df.sort_values(['mae']).head(25)
# Out:
#     ar_scale  rho_lower  beta_mu  beta_sigma  noise_scale       rmse  \
# 15     0.001        0.5        0       0.500        0.001   8.240316
# 6      0.001       -1.0        0       0.500        0.001   7.846904
# 0      0.001       -1.0        0       0.001        0.001   7.458316
# 9      0.001        0.5        0       0.001        0.001   7.455602
# 25     0.100       -1.0        0       0.500        0.100   8.249109
# 35     0.100        0.5        0       0.500        0.500   8.513765
# 34     0.100        0.5        0       0.500        0.100   8.265876
# 26     0.100       -1.0        0       0.500        0.500   8.677808
# 32     0.100        0.5        0       0.100        0.500   7.704034
# 3      0.001       -1.0        0       0.100        0.001  10.667254
# 29     0.100        0.5        0       0.001        0.500   7.695667
# 23     0.100       -1.0        0       0.100        0.500   7.758735
# 22     0.100       -1.0        0       0.100        0.100   7.900344
# ...

# %%
# chosen parameters - note the correlations are all bad
# wrt width
# 0.001	-1.0	0	0.500	0.001	7.846904	5.803964	0.406456	8.125469	0.428571
# wrt mae
# 0.001	-1.0	0	0.500	0.001	7.846904	5.803964	0.406456	8.125469	0.428571
